# %% [markdown]
# E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.
#
#
# Need not to create machine learning models /but still if anybody comes with it that is welcome.

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # importing data

# %%
#importing data
data= pd.read_excel("customer_retention_dataset.xlsx")

# %%
#1 checking data
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
data.tail()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %% [markdown]
# # Data Analysis

# %%
data.shape
# Out:
# (269, 71)

# %%
data.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
data.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
data.count()
# Out:
# 1Gender of respondent                                                   269
# 2 How old are you?                                                      269
# 3 Which city do you shop online from?                                   269
# 4 What is the Pin Code of where you shop online from?                   269
# 5 Since How Long You are Shopping Online ?                              269
#                                                                        ...
# Longer delivery period                                                  269
# Change in website/Application design                                    269
# Frequent disruption when moving from one page to another                269
# Website is as efficient as before                                       269
# Which of the Indian online retailer would you recommend to a friend?    269
# Length: 71, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# # EDA

# %%
#making heatmap for null values
plt.figure(figsize=(15,6))
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can see there is no null values in the dataset

# %%
#checking the data distribution using count plot for gender
plt.figure(figsize=(10,6))
ax = sns.countplot(data['1Gender of respondent'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['1Gender of respondent'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.show()

# %% [markdown]
# so we can see there are more number of women respondents as compare to.
# data is imbalanced because only 32% respondents are men rest of all others are women

# %%
#checking the data distribution using count plot for age groups
plt.figure(figsize=(15,6))
sns.countplot(data['2 How old are you? '])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['2 How old are you? '])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center',)
    k = k+1
plt.show()

# %% [markdown]
# we can see macimum number of people are from 31-40 age group. less than 20 years group people and 51 years age group people are not use online shopping sites.

# %%
#checking the data distribution using count plot for city
plt.figure(figsize=(10,6))
ax = sns.countplot(data['3 Which city do you shop online from?'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['3 Which city do you shop online from?'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1

plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# delhi has maximum number of people using e-commerce sites.than nida banglore and greater noida. only fer people are using online sites in bulandshehar and moradabad.

# %%
#checking the data distribution using count plot for time to use ecommerce
plt.figure(figsize=(10,6))
ax = sns.countplot(data['5 Since How Long You are Shopping Online ?'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['5 Since How Long You are Shopping Online ?'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.show()

# %% [markdown]
# maximum people are using the ecommerce sites more than 4 years and numbers are increasing for the people using shopping sites

# %%
#checking the data distribution using count plot for last time orderd
plt.figure(figsize=(10,6))
ax = sns.countplot(data['6 How many times you have made an online purchase in the past 1 year?'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['6 How many times you have made an online purchase in the past 1 year?'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# most of the people are place order less than 10 times and very fer people order more than 42 times in a year.

# %%
#checking the data distribution using count plot for mode of shopping
plt.figure(figsize=(10,6))
ax = sns.countplot(data['8 Which device do you use to access the online shopping?'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['8 Which device do you use to access the online shopping?'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.show()

# %% [markdown]
# most people are using smart phones and laptop for online shopping and few people are using tablets for online shopping

# %%
#checking the data distribution using count plot for channel for onine shipping
plt.figure(figsize=(10,6))
ax = sns.countplot(data['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.show()

# %% [markdown]
# we can see most of the people are using search engine for online shopping. and very few people are using content marketing and display advt.

# %%
#checking the data distribution using count plot for preffered payment methoed
plt.figure(figsize=(10,6))
ax = sns.countplot(data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.show()

# %% [markdown]
# most of the customers are using credit/debit card for payments. and few people are using e wallets

# %%
#checking the data distribution using count plot for does online shopping gives benefit
plt.figure(figsize=(10,6))
ax = sns.countplot(data['30 Online shopping gives monetary benefit and discounts'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['30 Online shopping gives monetary benefit and discounts'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.show()

# %% [markdown]
# most of the people believe that online shopping can gives tham moonetary benefits and online fer people suppose its not.

# %%
#checking the data distribution using count plot for convenience or not
plt.figure(figsize=(10,6))
ax = sns.countplot(data['32 Shopping online is convenient and flexible'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['32 Shopping online is convenient and flexible'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.show()

# %% [markdown]
# most of the people are strongly agree that online shopping is easy and convinint and very fer people believe its not

# %%
#checking the data distribution using count plot for Getting value for money spent'
plt.figure(figsize=(10,6))
ax = sns.countplot(data['47 Getting value for money spent'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['47 Getting value for money spent'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.show()

# %% [markdown]
# we can see maximum number of customers believe the they getting the value for money and very fer are not satisfy or they can't considered yet.

# %%
#checking the data distribution using count plot for Fast loading website speed of website and application'
plt.figure(figsize=(10,6))
ax = sns.countplot(data['Fast loading website speed of website and application'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['Fast loading website speed of website and application'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# amazon is the leading website for e-commerce and its used by most of the customers and flipkart is back in the list.

# %%
#checking the data distribution using count plot for Quickness to complete purchase'
plt.figure(figsize=(10,6))
ax = sns.countplot(data['Quickness to complete purchase'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['Quickness to complete purchase'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# amazon is the quickest site to complete the purchase in other words customers can complete the purchase fastest as compared to other websites and flipkart is slower in the list.

# %%
#checking the data distribution using count plot for Speedy order delivery '
plt.figure(figsize=(10,6))
ax = sns.countplot(data['Speedy order delivery '])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['Speedy order delivery '])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# amazon is the fastest site to deliver the products to the customers and flipkart is slowest.

# %%
#checking the data distribution using count plot for Perceived Trustworthiness'
plt.figure(figsize=(10,6))
ax = sns.countplot(data['Perceived Trustworthiness'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['Perceived Trustworthiness'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# amazon is top in trustworthiness for customers and myntra is not upto trustworthiness

# %%
#checking the data distribution using count plot for Security of customer financial information'
plt.figure(figsize=(10,6))
ax = sns.countplot(data['Security of customer financial information'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['Security of customer financial information'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# amazon is the best website for security of customer financial information and myntra does not suggested by costomers.

# %%
#checking the data distribution using count plot for Longer time to get logged in (promotion, sales period)'
plt.figure(figsize=(10,6))
ax = sns.countplot(data['Longer time to get logged in (promotion, sales period)'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['Longer time to get logged in (promotion, sales period)'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# amazon have all the goood things but amazon tooks to long to get logged in for users. and flipkart is quickest site for logging in

# %%
#checking the data distribution using count plot for Website is as efficient as before'
plt.figure(figsize=(10,6))
ax = sns.countplot(data['Website is as efficient as before'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['Website is as efficient as before'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# according to our data amazon.in is as effecient as it before but snapdeal, paytm and flipkart are changing.

# %%
#checking the data distribution using count plot for Which of the Indian online retailer would you recommend to a friend?'
plt.figure(figsize=(10,6))
ax = sns.countplot(data['Which of the Indian online retailer would you recommend to a friend?'])
k = 0
for i in ax.patches:
    h = i.get_height()
    t = len(data['Which of the Indian online retailer would you recommend to a friend?'])
    s = f"{h} ({round(h*100/t,2)}%)"
    plt.text(k,h/2,s,ha='center')
    k = k+1
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# most of the people are recommending amazon.in to their family and friends while very few people are recommeding paytm to their family and friends.

# %%
#Checking relationship between gender of respondent and age 
plt.figure(figsize=(16,5))
sns.countplot(data['1Gender of respondent'], hue=data['2 How old are you? '])
plt.show()

# %% [markdown]
# we can see most of male and female customers are of ages 21 to 50 years. minimum number of male and female customers are of age less than 20 years

# %%
#Checking relationship between gender of respondent and city 
plt.figure(figsize=(16,5))
sns.countplot(data['1Gender of respondent'], hue=data['3 Which city do you shop online from?'])
plt.show()

# %% [markdown]
# we can see most of female respodents are greater noida and most of male customers are from delhi.
# males and females both customers are from muradabad have less customers.

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
#encoding all the data
df = data.columns[data.dtypes == object]

#copy dataframe to another dataframe
df_encoded = data.copy()
df_new = {}
#encoding features
for feature in df:
    df_new[feature] = LabelEncoder()
    df_encoded[feature] = df_new[feature].fit_transform(data[feature])

# %%
#display the head of encoded dataframe
df_encoded.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      1                    1
# 1                      0                    0
# 2                      0                    0
# 3                      1                    0
# 4                      0                    0
#
#    3 Which city do you shop online from?  \
# 0                                      2
# 1                                      2
# 2                                      4
# 3                                      6
# 4                                      0
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           3
# ...

# %%
#checking the corelationship of all the variables
df_encoded.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                               0.046169
# 3 Which city do you shop online from?                            0.080912
# 4 What is the Pin Code of where you shop online...              -0.260365
# 5 Since How Long You are Shopping Online ?                      -0.057096
# ...                                                                   ...
# Longer delivery period                                           0.060838
# Change in website/Application design                            -0.164818
# Frequent disruption when moving from one page t...              -0.256638
# Website is as efficient as before                                0.055663
# Which of the Indian online retailer would you r...              -0.003372
#
#                                                     2 How old are you?   \
# ...

# %%
#plotting the heatmap for the correlation of variables
sns.heatmap(df_encoded.corr())
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# We can see in the above analysis the e-commerce is booming sector. and the number of users are increasing day by day as most of the customer find it enjoyable, value for money, they believe its realiable and there are some trustworthy sites like amazon which provide the secuity to the user and financial protection also. some sites are delaying the orders but they changing with the time so people are using the ecommerce site for shopping as using it is fun. so we can conclude that the e-commerce sites will boom in the future as number of customers increasing and its convinient. and amazon is leading the e-commerce market with the maximum number of buyers and maxium number of varieties of product on their site.
