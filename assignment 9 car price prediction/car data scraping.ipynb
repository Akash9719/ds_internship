# %%
# !pip install selenium

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
# Activating the chrome browser
driver = webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage of carwale
url = "https://www.cartrade.com/buy-used-cars/#sc=-1&so=-1&pn=1"
driver.get(url)
time.sleep(3)

# %%
car_url=[]
#scrapping the required details
start=0
end=100
for page in range(start,end):#for loop for scrapping 4 page
    url =driver.find_elements_by_xpath("//h2[@class='h2heading truncate']//a")
    for i in url:
        car_url.append(i.get_attribute("href"))
    nxt_button=driver.find_elements_by_xpath("//li[@class='next']//a")
    try:
        driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
    except:
        driver.get(nxt_button[0].get_attribute('href'))

# %%
df=pd.DataFrame({"car_url":car_url})
df
# Out:
#                                                 car_url
# 0     https://www.cartrade.com/buy-used-cars/kolkata...
# 1     https://www.cartrade.com/buy-used-cars/pune/ho...
# 2     https://www.cartrade.com/buy-used-cars/hyderab...
# 3     https://www.cartrade.com/buy-used-cars/delhi/h...
# 4     https://www.cartrade.com/buy-used-cars/mangalo...
# ...                                                 ...
# 2403  https://www.cartrade.com/buy-used-cars/chennai...
# 2404  https://www.cartrade.com/buy-used-cars/delhi/t...
# 2405  https://www.cartrade.com/buy-used-cars/hyderab...
# 2406  https://www.cartrade.com/buy-used-cars/ghaziab...
# 2407  https://www.cartrade.com/buy-used-cars/hyderab...
#
# [2408 rows x 1 columns]

# %%
car_url
# Out:
# ['https://www.cartrade.com/buy-used-cars/kolkata/maruti-suzuki/celerio/d2546807.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/pune/honda/mobilio/d2554677.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/hyderabad/maruti-suzuki/swift/d2531083.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/delhi/honda/city/d2553167.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/mangalore/ford/ecosport/d2515113.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/ghaziabad/hyundai/i10/d2560737.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/hyderabad/mercedes-benz/gla/d2535405.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/pune/kia/seltos/d2554647.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/chennai/honda/jazz/d2526533.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/chennai/maruti-suzuki/eeco/d2526925.html?dc=0',
#  'https://www.cartrade.com/buy-used-cars/chennai/honda/jazz/d2523795.html?dc=0',
# ...

# %%
car_brand=[]
car_name=[]
manufacturing_year=[]
location=[]
fuel_type=[]
kilometers_driven=[]
number_of_owners=[]
price=[]

for i in car_url:
    driver.get(i)
        
    try:
        brand = driver.find_element_by_xpath("//div[@class='wrapper v_content']//ul//li[4]")
        car_brand.append(brand.text)
    except:
        car_brand.append('-')
        
    try:
        name = driver.find_element_by_xpath("//div[@class='wrapper v_content']//ul//li[5]")
        car_name.append(name.text)
    except:
        car_name.append('-')
        
    try:
        year = driver.find_element_by_xpath("//table[@class='v_table']//tr[8]//td[2]")
        manufacturing_year.append(year.text)
    except:
        manufacturing_year.append('-')
        
    try:
        locations = driver.find_element_by_xpath("//table[@class='v_table']//tr[1]//td[2]")
        location.append(locations.text)
    except:
        location.append('-')
        
    try:
        fuel = driver.find_element_by_xpath("//table[@class='v_table']//tr[2]//td[2]")
        fuel_type.append(fuel.text)
    except:
        fuel_type.append('-')

    try:
        kms = driver.find_element_by_xpath("//table[@class='v_table']//tr[3]//td[2]")
        kilometers_driven.append(kms.text)
    except:
        kilometers_driven.append('-')
        
    try:
        owners = driver.find_element_by_xpath("//table[@class='v_table']//tr[5]//td[2]")
        number_of_owners.append(owners.text)
    except:
        number_of_owners.append('-')
        
    try:
        car_price = driver.find_element_by_xpath("//div[@class='pull-left']//span[2]")
        price.append(car_price.text)
    except:
        price.append('-')

# %%
df=pd.DataFrame({"car_brand":car_brand,"car_name":car_name,
                "manufacturing_year":manufacturing_year,"location":location,"fuel_type":fuel_type,"kilometers_driven":kilometers_driven,"number_of_owners":number_of_owners,"price":price})
df
# Out:
#            car_brand   car_name manufacturing_year   location fuel_type  \
# 0     Maruti Suzuki»   Celerio»               2016    Kolkata    Petrol
# 1             Honda»   Mobilio»               2015       Pune    Petrol
# 2     Maruti Suzuki»     Swift»               2009  Hyderabad    Petrol
# 3             Honda»      City»               2016      Delhi    Petrol
# 4              Ford»  Ecosport»               2013  Mangalore    Diesel
# ...              ...        ...                ...        ...       ...
# 2403     Mitsubishi»    Pajero»               2011    Chennai    Diesel
# 2404         Toyota»  Fortuner»               2013      Delhi    Diesel
# 2405           Ford»  Ecosport»               2013  Hyderabad    Diesel
# 2406          Honda»     Amaze»               2019  Ghaziabad    Petrol
# 2407          Honda»     Amaze»               2019  Hyderabad    Petrol
#
#      kilometers_driven number_of_owners      price
# 0           45,386 Kms            First  3.29 Lakh
# ...

# %%
df.to_excel('df.xlsx')

# %%
# Activating the chrome browser
driver = webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage of carwale
url = "https://www.cartrade.com/buy-used-cars/#sc=-1&so=-1&pn=1"
driver.get(url)
time.sleep(3)

# %%
car_url=[]
#scrapping the required details
start=101
end=210
for page in range(start,end):#for loop for scrapping 4 page
    url =driver.find_elements_by_xpath("//h2[@class='h2heading truncate']//a")
    for i in url:
        car_url.append(i.get_attribute("href"))
    nxt_button=driver.find_elements_by_xpath("//li[@class='next']//a")
    try:
        driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
    except:
        driver.get(nxt_button[0].get_attribute('href'))

# %%
df1=pd.DataFrame({"car_url":car_url})
df1
# Out:
#                                                 car_url
# 0     https://www.cartrade.com/buy-used-cars/kolkata...
# 1     https://www.cartrade.com/buy-used-cars/kolkata...
# 2     https://www.cartrade.com/buy-used-cars/chennai...
# 3     https://www.cartrade.com/buy-used-cars/hyderab...
# 4     https://www.cartrade.com/buy-used-cars/mumbai/...
# ...                                                 ...
# 2611  https://www.cartrade.com/buy-used-cars/delhi/m...
# 2612  https://www.cartrade.com/buy-used-cars/lucknow...
# 2613  https://www.cartrade.com/buy-used-cars/delhi/s...
# 2614  https://www.cartrade.com/buy-used-cars/dehradu...
# 2615  https://www.cartrade.com/buy-used-cars/bangalo...
#
# [2616 rows x 1 columns]

# %%
car_brand=[]
car_name=[]
manufacturing_year=[]
location=[]
fuel_type=[]
kilometers_driven=[]
number_of_owners=[]
price=[]

for i in car_url:
    driver.get(i)
        
    try:
        brand = driver.find_element_by_xpath("//div[@class='wrapper v_content']//ul//li[4]")
        car_brand.append(brand.text)
    except:
        car_brand.append('-')
        
    try:
        name = driver.find_element_by_xpath("//div[@class='wrapper v_content']//ul//li[5]")
        car_name.append(name.text)
    except:
        car_name.append('-')
        
    try:
        year = driver.find_element_by_xpath("//table[@class='v_table']//tr[8]//td[2]")
        manufacturing_year.append(year.text)
    except:
        manufacturing_year.append('-')
        
    try:
        locations = driver.find_element_by_xpath("//table[@class='v_table']//tr[1]//td[2]")
        location.append(locations.text)
    except:
        location.append('-')
        
    try:
        fuel = driver.find_element_by_xpath("//table[@class='v_table']//tr[2]//td[2]")
        fuel_type.append(fuel.text)
    except:
        fuel_type.append('-')

    try:
        kms = driver.find_element_by_xpath("//table[@class='v_table']//tr[3]//td[2]")
        kilometers_driven.append(kms.text)
    except:
        kilometers_driven.append('-')
        
    try:
        owners = driver.find_element_by_xpath("//table[@class='v_table']//tr[5]//td[2]")
        number_of_owners.append(owners.text)
    except:
        number_of_owners.append('-')
        
    try:
        car_price = driver.find_element_by_xpath("//div[@class='pull-left']//span[2]")
        price.append(car_price.text)
    except:
        price.append('-')

# %%
df1=pd.DataFrame({"car_brand":car_brand,"car_name":car_name,
                "manufacturing_year":manufacturing_year,"location":location,"fuel_type":fuel_type,"kilometers_driven":kilometers_driven,"number_of_owners":number_of_owners,"price":price})
df1
# Out:
#            car_brand   car_name manufacturing_year   location fuel_type  \
# 0            Nissan»     Sunny»               2012    Kolkata    Petrol
# 1         Chevrolet»      Aveo»               2010    Kolkata    Petrol
# 2        Mitsubishi»    Pajero»               2011    Chennai    Diesel
# 3              Ford»  Ecosport»               2013  Hyderabad    Diesel
# 4            Toyota»    Innova»               2017     Mumbai    Diesel
# ...              ...        ...                ...        ...       ...
# 2611  Mercedes-Benz»   S-Class»               2016      Delhi    Petrol
# 2612            Kia»  Carnival»               2020    Lucknow    Diesel
# 2613          Skoda»    Superb»               2015      Delhi    Petrol
# 2614          Honda»   Mobilio»               2015   Dehradun    Petrol
# 2615  Maruti Suzuki»      Ciaz»               2015  Bangalore    Petrol
#
#      kilometers_driven number_of_owners       price
# ...

# %%
df1.to_excel('df1.xlsx')

# %%
cars_data=pd.concat([df,df1],axis=0,ignore_index=True)

# %%
cars_data
# Out:
#            car_brand   car_name manufacturing_year   location fuel_type  \
# 0     Maruti Suzuki»   Celerio»               2016    Kolkata    Petrol
# 1             Honda»   Mobilio»               2015       Pune    Petrol
# 2     Maruti Suzuki»     Swift»               2009  Hyderabad    Petrol
# 3             Honda»      City»               2016      Delhi    Petrol
# 4              Ford»  Ecosport»               2013  Mangalore    Diesel
# ...              ...        ...                ...        ...       ...
# 5019  Mercedes-Benz»   S-Class»               2016      Delhi    Petrol
# 5020            Kia»  Carnival»               2020    Lucknow    Diesel
# 5021          Skoda»    Superb»               2015      Delhi    Petrol
# 5022          Honda»   Mobilio»               2015   Dehradun    Petrol
# 5023  Maruti Suzuki»      Ciaz»               2015  Bangalore    Petrol
#
#      kilometers_driven number_of_owners       price
# ...

# %%
cars_data.to_excel('cars_data.xlsx')
